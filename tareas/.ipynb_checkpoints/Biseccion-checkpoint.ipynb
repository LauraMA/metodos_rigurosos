# %% [markdown]
# **Método de la bisección.**

# %% [markdown]
# Se incluyen dos códigos para el método de la Bisección, el primero es de practica por lo cual incluye varios *print* para verificar el funcionamiento del código. El segundo, es una ligera modificación del primero (no hace prints), imprime una lista de **intervalos** donde "puede"  haber una raíz (pues esto depende de la tolerancia que hayamos dado y de que la imagen -bajo la función parametro-  contenga al 'cero' ).

# %%
from intervalo import *

# %%
# código de práctica
def met_biseccion2(funcion, interval, tolerancia):
    u""" Implementación del método de la bisección para intervalos de la clase intervalo.
    La función toma como parámetros una función f previamente definida, el intervalo sobre el cual 
    se quiere trabajar y una tolerancia para específicar un error para el cero .
    """
    f = funcion
    A = interval
    raices = []
    print A
    f_lo, f_hi = f(A.lo), f(A.hi)
    A_middle = A.middle()
        
    if f(A_middle) == 0 :
        print "estoy aqui 1"
        raices.append(Intervalo(A_middle))
    
    if f_lo * f_hi <= 0 :
        if  A.hi - A.lo <  tolerancia :
            raices.append(A)
        else : 
            A_left, A_right = chop(A)
               
            l_aux1 = met_biseccion2(f, A_left, tolerancia)
            if l_aux1 != [] :
                print "estoy aqui 2"
                raices = raices + l_aux1
            
            l_aux2 = met_biseccion2(f, A_right, tolerancia)
            if l_aux2 != [] :
                print "estoy aqui 3"
                raices.extend(l_aux2)
                    
    elif f_lo * f_hi > 0 :
        if 0 in f(A) :
            print "A={}".format(f(A))
            A_left, A_right = chop(A)
                
            if f(A_middle) == 0 :
                print "estoy aqui 4"
                raices.append(Intervalo(A_middle))
                
            l_aux1 = met_biseccion2(f, A_left, tolerancia)
            if l_aux1 != [] :
                print "estoy aqui 5"
                raices.extend(l_aux1)
            
            l_aux2 = met_biseccion2(f, A_right, tolerancia)
            if l_aux2 != [] :
                print "estoy aqui 6"
                raices.extend(l_aux2)
    elif f_lo == 0:
        raices.extend(Intervalo(f_lo, f_lo))
    elif f_hi == 0:
        raices.extend(Intervalo(f_hi, f_hi))
    return raices

# %%
def met_biseccion3(funcion, interval, tolerancia):
    u""" Implementación del método de la bisección para intervalos de la clase intervalo.
    La función toma como parámetros una función f previamente definida, el intervalo sobre el cual 
    se quiere trabajar y una tolerancia para específicar un error para la raíz (cero).
    """
    f = funcion
    A = interval
    raices = []

    f_lo, f_hi = f(A.lo), f(A.hi)
    A_middle = A.middle()
            
    if f(A_middle) == 0 :
        raices.append(Intervalo(A_middle))
        
    if f_lo * f_hi <= 0 :
        if  A.hi - A.lo <  tolerancia :
            raices.append(A)
        else : 
            A_left, A_right = chop(A)                         
            l_aux1 = met_biseccion3(f, A_left, tolerancia)
            l_aux2 = met_biseccion3(f, A_right, tolerancia)
            
            if l_aux1 != [] :
                raices = raices + l_aux1
        
            if l_aux2 != [] :
                raices.extend(l_aux2)
                    
    elif f_lo * f_hi > 0 :
        if 0 in f(A) :
            A_left, A_right = chop(A)
            l_aux1 = met_biseccion3(f, A_left, tolerancia)
            l_aux2 = met_biseccion3(f, A_right, tolerancia)
            
            if l_aux1 != [] :
                raices.extend(l_aux1)
            
            if l_aux2 != [] :
                raices.extend(l_aux2)
    elif f_lo == 0:
        raices = raices +[Intervalo(f_lo, f_lo)]
        
    elif f_hi == 0:
        raices = raices + [Intervalo(f_hi, f_hi)] 
        
    return raices

# %%
# reducción del código anterior
# Además se considera que si el punto medio del intervalo es un cero, para no obtenerlo varias veces,
# entonces no partimos el intervalo en mitades sino en dos intervalos, uno de 3/4 partes y otro de una cuarta parte.

# Esta función regresa una lista de intervalos que "pueden" contener raíz y a diferencia del anterior la lista 
# tiene "tantos" elementos como raices (pero no cuenta multiplicidad).
##################    ###################     #########################     #####################    ########################

def met_biseccion4(funcion, interval, tolerancia):
    u""" Implementación del método de la bisección para intervalos de la clase intervalo.
    La función toma como parámetros una función f previamente definida, el intervalo sobre el cual 
    se quiere trabajar y una tolerancia para específicar un error para la raíz (cero).
    """
    f = funcion
    A = interval
    raices = []

    f_Alo, f_Ahi = f(A.lo), f(A.hi)
    A_middle = A.middle()
    f_Amiddle = f(A_middle)
    
    if 0 in f(A):
        
        if  A.width() <  tolerancia :
            if f_Alo * f_Ahi < 0 : 
                raices.append(A)
            
        else: 
            A_left, A_right = chop(A)
            A_rmiddle = A_right.middle()
        
            if f_Amiddle == 0 :
                A_left , A_right = Intervalo(A.lo, A_rmiddle), Intervalo(A_rmiddle,A.hi)    
            
            l_aux1 = met_biseccion4(f, A_left, tolerancia)
            l_aux2 = met_biseccion4(f, A_right, tolerancia)
            
            if l_aux1 != [] :
                raices.extend(l_aux1)
                
            if l_aux2 != [] :
                raices.extend(l_aux2)

    return raices

# %% [markdown]
# *Definimos algunas funciones*

# %%
def identidad(x):
    return x

# %%
def cte2(x):
    return Intervalo(2)

# %%
def g(x):
    return x*x -1

# %%
def h(x) :
    return x*x*x-3*x*x +2*x

# %%
def h2(x):
    return x*(x-1)*(x-2)

# %% [markdown]
# Calculamos las raices (intervalos que contengan una raiz) para las funciones anteriores con los dos métodos anteriores.

# %%
met_biseccion2(identidad, Intervalo(-1,1.5), 1/10.)
# Out:
# [-1,1.5]
# [-1,0.25]
# [-1,-0.375]
# [-0.375,0.25]
# [-0.375,-0.0625]
# [-0.0625,0.25]
# [-0.0625,0.09375]
# [-0.0625,0.015625]
# estoy aqui 2
# [0.015625,0.09375]
# estoy aqui 2
# [0.09375,0.25]
# estoy aqui 3
# estoy aqui 3
# estoy aqui 2
# [0.25,1.5]
# [Intervalo [-0.0625,0.015625]]

# %%
met_biseccion3(identidad, Intervalo(-1,1.5), 1/10.)
# Out:
# [Intervalo [-0.0625,0.015625]]

# %%
met_biseccion2(cte2, Intervalo(-1,1), 1/10. )
# Out:
# [-1,1]
# []

# %%
met_biseccion3(cte2, Intervalo(-1,1), 1/10. )
# Out:
# []

# %%
met_biseccion2(g, Intervalo(-2,2), 1/10. ) 
# para el intervalo(-2,2) si no funciona el código puede ser porque
# el archivo intervalo.py tiene el código de las funciones middle y radio como:    algo/2
# y en realidad debe ser:    algo/2. (es decir falta el punto para que la division no sea cero).
# Out:
# [-2,2]
# A=[-5,3]
# [-2,0.0]
# estoy aqui 1
# [-2,-1.0]
# [-2,-1.5]
# [-1.5,-1.0]
# [-1.5,-1.25]
# [-1.25,-1.0]
# [-1.25,-1.125]
# [-1.125,-1.0]
# [-1.125,-1.0625]
# [-1.0625,-1.0]
# estoy aqui 3
# estoy aqui 3
# estoy aqui 3
# estoy aqui 3
# estoy aqui 2
# [-1.0,0.0]
# [-1.0,-0.5]
# [-1.0,-0.75]
# [-1.0,-0.875]
# [-1.0,-0.9375]
# estoy aqui 2
# [-0.9375,-0.875]
# estoy aqui 2
# [-0.875,-0.75]
# estoy aqui 2
# [-0.75,-0.5]
# estoy aqui 2
# [-0.5,0.0]
# estoy aqui 3
# estoy aqui 5
# [0.0,2]
# estoy aqui 1
# [0.0,1.0]
# [0.0,0.5]
# [0.5,1.0]
# [0.5,0.75]
# [0.75,1.0]
# [0.75,0.875]
# [0.875,1.0]
# [0.875,0.9375]
# [0.9375,1.0]
# estoy aqui 3
# estoy aqui 3
# estoy aqui 3
# estoy aqui 3
# estoy aqui 2
# [1.0,2]
# [1.0,1.5]
# [1.0,1.25]
# [1.0,1.125]
# [1.0,1.0625]
# estoy aqui 2
# [1.0625,1.125]
# estoy aqui 2
# [1.125,1.25]
# estoy aqui 2
# [1.25,1.5]
# estoy aqui 2
# [1.5,2]
# estoy aqui 3
# estoy aqui 6
# [Intervalo [-1.0,-1.0],
#  Intervalo [-1.0625,-1.0],
#  Intervalo [-1.0,-0.9375],
#  Intervalo [1.0,1.0],
#  Intervalo [0.9375,1.0],
#  Intervalo [1.0,1.0625]]

# %%
met_biseccion3(g, Intervalo(-2, 1.5), 1/20.)  # en este caso debe  encontrar dos raices
# Out:
# [Intervalo [-1.015625,-0.98828125], Intervalo [0.98046875,1.0078125]]

# %%
met_biseccion3(g, Intervalo(0, 1.5), 1/20.) # en este caso debe encontrar solo una raiz
# Out:
# [Intervalo [0.984375,1.03125]]

# %%
met_biseccion2(h, Intervalo(-1,2.5), 1/10.) # debemos hallar tres raices
# Out:
# [-1,2.5]
# [-1,0.75]
# [-1,-0.125]
# [-0.125,0.75]
# [-0.125,0.3125]
# [-0.125,0.09375]
# [-0.125,-0.015625]
# [-0.015625,0.09375]
# [-0.015625,0.0390625]
# estoy aqui 2
# [0.0390625,0.09375]
# estoy aqui 3
# estoy aqui 2
# [0.09375,0.3125]
# A=[-0.104644775391,0.629150390625]
# [0.09375,0.203125]
# [0.203125,0.3125]
# estoy aqui 2
# [0.3125,0.75]
# A=[-1.03198242188,1.62890625]
# [0.3125,0.53125]
# A=[-0.191162109375,0.919464111328]
# [0.3125,0.421875]
# [0.421875,0.53125]
# [0.53125,0.75]
# A=[-0.475067138672,1.0751953125]
# [0.53125,0.640625]
# A=[-0.0187683105469,0.697483062744]
# [0.53125,0.5859375]
# [0.5859375,0.640625]
# [0.640625,0.75]
# A=[-0.143337249756,0.690673828125]
# [0.640625,0.6953125]
# [0.6953125,0.75]
# estoy aqui 3
# estoy aqui 2
# [0.75,2.5]
# A=[-16.828125,18.9375]
# [0.75,1.625]
# [0.75,1.1875]
# [0.75,0.96875]
# A=[-0.8935546875,1.15914916992]
# [0.75,0.859375]
# A=[-0.293701171875,0.665920257568]
# [0.75,0.8046875]
# A=[-0.0206909179688,0.442927837372]
# [0.75,0.77734375]
# [0.77734375,0.8046875]
# [0.8046875,0.859375]
# A=[-0.0851483345032,0.4108543396]
# [0.8046875,0.83203125]
# [0.83203125,0.859375]
# [0.859375,0.96875]
# A=[-0.462009429932,0.631072998047]
# [0.859375,0.9140625]
# A=[-0.15311050415,0.376257419586]
# [0.859375,0.88671875]
# A=[-0.00539016723633,0.255061805248]
# [0.859375,0.873046875]
# [0.873046875,0.88671875]
# [0.88671875,0.9140625]
# A=[-0.0358927845955,0.233023166656]
# [0.88671875,0.900390625]
# [0.900390625,0.9140625]
# [0.9140625,0.96875]
# A=[-0.223596096039,0.340118408203]
# [0.9140625,0.94140625]
# A=[-0.066903591156,0.210599005222]
# [0.9140625,0.927734375]
# [0.927734375,0.94140625]
# A=[-0.00477574020624,0.135056555271]
# [0.927734375,0.9345703125]
# [0.9345703125,0.94140625]
# [0.94140625,0.96875]
# A=[-0.0982999205589,0.187911987305]
# [0.94140625,0.955078125]
# A=[-0.0193929076195,0.122616715729]
# [0.94140625,0.9482421875]
# [0.9482421875,0.955078125]
# [0.955078125,0.96875]
# A=[-0.0340757891536,0.110126495361]
# [0.955078125,0.9619140625]
# [0.9619140625,0.96875]
# A=[-0.00156300421804,0.0708131790161]
# [0.9619140625,0.96533203125]
# [0.96533203125,0.96875]
# [0.96875,1.1875]
# [0.96875,1.078125]
# [0.96875,1.0234375]
# estoy aqui 2
# [1.0234375,1.078125]
# A=[-0.368212223053,0.267139434814]
# [1.0234375,1.05078125]
# A=[-0.193575382233,0.119500458241]
# [1.0234375,1.037109375]
# A=[-0.107939243317,0.0474563464522]
# [1.0234375,1.0302734375]
# A=[-0.0655417442322,0.0118714263663]
# [1.0234375,1.02685546875]
# [1.02685546875,1.0302734375]
# [1.0302734375,1.037109375]
# A=[-0.0726431915537,0.00533922761679]
# [1.0302734375,1.03369140625]
# [1.03369140625,1.037109375]
# [1.037109375,1.05078125]
# A=[-0.122694410384,0.0349858403206]
# [1.037109375,1.0439453125]
# [1.0439453125,1.05078125]
# [1.05078125,1.078125]
# A=[-0.225287139416,0.0969886779785]
# [1.05078125,1.064453125]
# A=[-0.137407958508,0.022572286427]
# [1.05078125,1.0576171875]
# [1.0576171875,1.064453125]
# [1.064453125,1.078125]
# A=[-0.152064554393,0.0102310180664]
# [1.064453125,1.0712890625]
# [1.0712890625,1.078125]
# estoy aqui 2
# [1.078125,1.1875]
# A=[-0.821056365967,0.5625]
# [1.078125,1.1328125]
# A=[-0.440380096436,0.232262134552]
# [1.078125,1.10546875]
# A=[-0.256771087646,0.0748273730278]
# [1.078125,1.091796875]
# [1.091796875,1.10546875]
# [1.10546875,1.1328125]
# A=[-0.287904560566,0.0531392097473]
# [1.10546875,1.119140625]
# [1.119140625,1.1328125]
# [1.1328125,1.1875]
# A=[-0.511146068573,0.199768066406]
# [1.1328125,1.16015625]
# A=[-0.318564891815,0.032046854496]
# [1.1328125,1.146484375]
# [1.146484375,1.16015625]
# [1.16015625,1.1875]
# A=[-0.348629415035,0.0116729736328]
# [1.16015625,1.173828125]
# [1.173828125,1.1875]
# estoy aqui 3
# estoy aqui 2
# [1.1875,1.625]
# A=[-3.87231445312,3.310546875]
# [1.1875,1.40625]
# A=[-1.88305664062,1.36294555664]
# [1.1875,1.296875]
# A=[-0.99609375,0.54447555542]
# [1.1875,1.2421875]
# A=[-0.579528808594,0.170638561249]
# [1.1875,1.21484375]
# [1.21484375,1.2421875]
# [1.2421875,1.296875]
# A=[-0.644546985626,0.145854949951]
# [1.2421875,1.26953125]
# [1.26953125,1.296875]
# [1.296875,1.40625]
# A=[-1.15767288208,0.547760009766]
# [1.296875,1.3515625]
# A=[-0.705219268799,0.126398563385]
# [1.296875,1.32421875]
# [1.32421875,1.3515625]
# [1.3515625,1.40625]
# A=[-0.76056432724,0.113250732422]
# [1.3515625,1.37890625]
# [1.37890625,1.40625]
# [1.40625,1.625]
# A=[-2.32846069336,1.6083984375]
# [1.40625,1.515625]
# A=[-1.29794311523,0.58020401001]
# [1.40625,1.4609375]
# A=[-0.809600830078,0.107392787933]
# [1.40625,1.43359375]
# [1.43359375,1.4609375]
# [1.4609375,1.515625]
# A=[-0.851347446442,0.109806060791]
# [1.4609375,1.48828125]
# [1.48828125,1.515625]
# [1.515625,1.625]
# A=[-1.40905380249,0.649658203125]
# [1.515625,1.5703125]
# A=[-0.884822845459,0.121471881866]
# [1.515625,1.54296875]
# [1.54296875,1.5703125]
# [1.5703125,1.625]
# A=[-0.909045696259,0.143371582031]
# [1.5703125,1.59765625]
# [1.59765625,1.625]
# estoy aqui 5
# [1.625,2.5]
# [1.625,2.0625]
# [1.625,1.84375]
# A=[-2.6572265625,2.03329467773]
# [1.625,1.734375]
# A=[-1.48315429688,0.763973236084]
# [1.625,1.6796875]
# A=[-0.923034667969,0.176486492157]
# [1.625,1.65234375]
# [1.65234375,1.6796875]
# [1.6796875,1.734375]
# A=[-0.925808429718,0.221797943115]
# [1.6796875,1.70703125]
# [1.70703125,1.734375]
# [1.734375,1.84375]
# A=[-1.51239395142,0.930999755859]
# [1.734375,1.7890625]
# A=[-0.916385650635,0.280287265778]
# [1.734375,1.76171875]
# [1.76171875,1.7890625]
# [1.7890625,1.84375]
# A=[-0.893784999847,0.352935791016]
# [1.7890625,1.81640625]
# A=[-0.593537807465,0.0235052704811]
# [1.7890625,1.802734375]
# [1.802734375,1.81640625]
# [1.81640625,1.84375]
# A=[-0.5725030303,0.0571746826172]
# [1.81640625,1.830078125]
# [1.830078125,1.84375]
# [1.84375,2.0625]
# [1.84375,1.953125]
# A=[-1.48892211914,1.15858840942]
# [1.84375,1.8984375]
# A=[-0.857025146484,0.440724849701]
# [1.84375,1.87109375]
# A=[-0.547805786133,0.0946292281151]
# [1.84375,1.857421875]
# [1.857421875,1.87109375]
# [1.87109375,1.8984375]
# A=[-0.519323408604,0.135991573334]
# [1.87109375,1.884765625]
# [1.884765625,1.8984375]
# [1.8984375,1.953125]
# A=[-0.805124759674,0.544635772705]
# [1.8984375,1.92578125]
# A=[-0.486933231354,0.181384384632]
# [1.8984375,1.912109375]
# A=[-0.329519748688,0.0030060634017]
# [1.8984375,1.9052734375]
# [1.9052734375,1.912109375]
# [1.912109375,1.92578125]
# A=[-0.310699380934,0.0250924229622]
# [1.912109375,1.9189453125]
# [1.9189453125,1.92578125]
# [1.92578125,1.953125]
# A=[-0.450512588024,0.230930328369]
# [1.92578125,1.939453125]
# A=[-0.290856063366,0.0482170656323]
# [1.92578125,1.9326171875]
# [1.9326171875,1.939453125]
# [1.939453125,1.953125]
# A=[-0.269974462688,0.072395324707]
# [1.939453125,1.9462890625]
# [1.9462890625,1.953125]
# [1.953125,2.0625]
# [1.953125,2.0078125]
# estoy aqui 2
# [2.0078125,2.0625]
# A=[-0.651977062225,0.804748535156]
# [2.0078125,2.03515625]
# A=[-0.315841197968,0.405713617802]
# [2.0078125,2.021484375]
# A=[-0.149455547333,0.209627531469]
# [2.0078125,2.0146484375]
# A=[-0.0666832923889,0.112435623072]
# [2.0078125,2.01123046875]
# A=[-0.0254023075104,0.0640516140265]
# [2.0078125,2.00952148438]
# A=[-0.00478810071945,0.0399124909745]
# [2.0078125,2.00866699219]
# [2.00866699219,2.00952148438]
# [2.00952148438,2.01123046875]
# A=[-0.00129839884175,0.0434549310012]
# [2.00952148438,2.01037597656]
# [2.01037597656,2.01123046875]
# [2.01123046875,2.0146484375]
# A=[-0.0184402606683,0.0712247332558]
# [2.01123046875,2.01293945312]
# [2.01293945312,2.0146484375]
# [2.0146484375,2.021484375]
# A=[-0.0528285065666,0.127135656774]
# [2.0146484375,2.01806640625]
# A=[-0.0114073315635,0.0784689743305]
# [2.0146484375,2.01635742188]
# [2.01635742188,2.01806640625]
# [2.01806640625,2.021484375]
# A=[-0.00430328061339,0.0857845768332]
# [2.01806640625,2.01977539062]
# [2.01977539062,2.021484375]
# [2.021484375,2.03515625]
# A=[-0.122022248805,0.240449488163]
# [2.021484375,2.0283203125]
# A=[-0.0386892333627,0.142122094519]
# [2.021484375,2.02490234375]
# [2.02490234375,2.0283203125]
# [2.0283203125,2.03515625]
# A=[-0.0242635561153,0.15739685297]
# [2.0283203125,2.03173828125]
# [2.03173828125,2.03515625]
# [2.03515625,2.0625]
# A=[-0.26207202673,0.473098754883]
# [2.03515625,2.048828125]
# A=[-0.0934433341026,0.272432394326]
# [2.03515625,2.0419921875]
# A=[-0.00954955816269,0.172961848788]
# [2.03515625,2.03857421875]
# [2.03857421875,2.0419921875]
# [2.0419921875,2.048828125]
# [2.048828125,2.0625]
# A=[-0.0637034699321,0.305591583252]
# [2.048828125,2.0556640625]
# [2.0556640625,2.0625]
# estoy aqui 3
# estoy aqui 3
# estoy aqui 2
# [2.0625,2.5]
# A=[-5.85131835938,7.86328125]
# [2.0625,2.28125]
# A=[-2.71362304688,3.67263793945]
# [2.0625,2.171875]
# A=[-1.25244140625,1.82685470581]
# [2.0625,2.1171875]
# A=[-0.548767089844,0.962913036346]
# [2.0625,2.08984375]
# A=[-0.203659057617,0.545250356197]
# [2.0625,2.076171875]
# A=[-0.032787322998,0.339942388237]
# [2.0625,2.0693359375]
# [2.0693359375,2.076171875]
# [2.076171875,2.08984375]
# A=[-0.000679560005665,0.375500142574]
# [2.076171875,2.0830078125]
# [2.0830078125,2.08984375]
# [2.08984375,2.1171875]
# A=[-0.140479624271,0.622291088104]
# [2.08984375,2.103515625]
# [2.103515625,2.1171875]
# [2.1171875,2.171875]
# A=[-0.426491260529,1.14112472534]
# [2.1171875,2.14453125]
# A=[-0.0724110603333,0.704343616962]
# [2.1171875,2.130859375]
# [2.130859375,2.14453125]
# [2.14453125,2.171875]
# [2.171875,2.28125]
# A=[-1.02373123169,2.28323364258]
# [2.171875,2.2265625]
# A=[-0.284168243408,1.34036493301]
# [2.171875,2.19921875]
# [2.19921875,2.2265625]
# [2.2265625,2.28125]
# A=[-0.120816707611,1.56161499023]
# [2.2265625,2.25390625]
# [2.25390625,2.28125]
# [2.28125,2.5]
# A=[-2.31564331055,5.0126953125]
# [2.28125,2.390625]
# A=[-0.710906982422,2.83157730103]
# [2.28125,2.3359375]
# [2.3359375,2.390625]
# [2.390625,2.5]
# A=[-0.306118011475,3.47973632812]
# [2.390625,2.4453125]
# [2.4453125,2.5]
# estoy aqui 6
# estoy aqui 3
# [Intervalo [-0.015625,0.0390625],
#  Intervalo [0.96875,1.0234375],
#  Intervalo [1.953125,2.0078125]]

# %%
met_biseccion3(h, Intervalo(0,1.5), 1/10.)  # dos raices
# Out:
# [Intervalo [0,0.09375], Intervalo [0.9375,1.03125]]

# %%
met_biseccion3(h, Intervalo(1.5,4), 1/10.)  #  una raiz
# Out:
# [Intervalo [1.96875,2.046875]]

# %%
met_biseccion3(h, Intervalo(2.5,4), 1/10.)  #  ninguna raiz
# Out:
# []

# %%
met_biseccion3(h, Intervalo(-1,3.3), 0.3)
# Out:
# [Intervalo [-0.19375,0.075],
#  Intervalo [0.88125,1.15],
#  Intervalo [1.95625,2.225]]

# %%
met_biseccion2(h, Intervalo(-1,5), 1/10. )
# Out:
# [-1,5]
# estoy aqui 1
# [-1,2.0]
# [-1,0.5]
# [-1,-0.25]
# [-0.25,0.5]
# [-0.25,0.125]
# [-0.25,-0.0625]
# [-0.0625,0.125]
# [-0.0625,0.03125]
# estoy aqui 2
# [0.03125,0.125]
# estoy aqui 3
# estoy aqui 2
# [0.125,0.5]
# A=[-0.498046875,1.078125]
# [0.125,0.3125]
# A=[-0.041015625,0.608642578125]
# [0.125,0.21875]
# [0.21875,0.3125]
# [0.3125,0.5]
# A=[-0.094482421875,0.83203125]
# [0.3125,0.40625]
# [0.40625,0.5]
# estoy aqui 3
# estoy aqui 2
# [0.5,2.0]
# [0.5,1.25]
# [0.5,0.875]
# A=[-1.171875,1.669921875]
# [0.5,0.6875]
# A=[-0.29296875,0.949951171875]
# [0.5,0.59375]
# [0.59375,0.6875]
# A=[-0.0211486816406,0.642333984375]
# [0.59375,0.640625]
# [0.640625,0.6875]
# [0.6875,0.875]
# A=[-0.596923828125,1.001953125]
# [0.6875,0.78125]
# A=[-0.131103515625,0.621368408203]
# [0.6875,0.734375]
# [0.734375,0.78125]
# [0.78125,0.875]
# A=[-0.257537841797,0.5888671875]
# [0.78125,0.828125]
# A=[-0.0180358886719,0.393115997314]
# [0.78125,0.8046875]
# [0.8046875,0.828125]
# [0.828125,0.875]
# A=[-0.0727043151855,0.362548828125]
# [0.828125,0.8515625]
# [0.8515625,0.875]
# [0.875,1.25]
# [0.875,1.0625]
# [0.875,0.96875]
# A=[-0.3955078125,0.549774169922]
# [0.875,0.921875]
# A=[-0.129638671875,0.330333709717]
# [0.875,0.8984375]
# A=[-0.00164794921875,0.225209712982]
# [0.875,0.88671875]
# [0.88671875,0.8984375]
# [0.8984375,0.921875]
# A=[-0.0274758338928,0.205638885498]
# [0.8984375,0.91015625]
# [0.91015625,0.921875]
# [0.921875,0.96875]
# A=[-0.188220977783,0.297088623047]
# [0.921875,0.9453125]
# A=[-0.053638458252,0.185810565948]
# [0.921875,0.93359375]
# [0.93359375,0.9453125]
# [0.9453125,0.96875]
# A=[-0.0800585746765,0.165802001953]
# [0.9453125,0.95703125]
# A=[-0.0123553276062,0.109768688679]
# [0.9453125,0.951171875]
# [0.951171875,0.95703125]
# [0.95703125,0.96875]
# A=[-0.0248138308525,0.0989227294922]
# [0.95703125,0.962890625]
# [0.962890625,0.96875]
# [0.96875,1.0625]
# estoy aqui 3
# estoy aqui 2
# [1.0625,1.25]
# A=[-1.36303710938,1.06640625]
# [1.0625,1.15625]
# A=[-0.686279296875,0.471588134766]
# [1.0625,1.109375]
# A=[-0.36767578125,0.197353363037]
# [1.0625,1.0859375]
# A=[-0.213317871094,0.0657591819763]
# [1.0625,1.07421875]
# A=[-0.13737487793,0.0013090968132]
# [1.0625,1.068359375]
# [1.068359375,1.07421875]
# [1.07421875,1.0859375]
# [1.0859375,1.109375]
# A=[-0.239660739899,0.0462913513184]
# [1.0859375,1.09765625]
# [1.09765625,1.109375]
# [1.109375,1.15625]
# A=[-0.426670074463,0.166168212891]
# [1.109375,1.1328125]
# A=[-0.265720367432,0.027184009552]
# [1.109375,1.12109375]
# [1.12109375,1.1328125]
# [1.1328125,1.15625]
# A=[-0.291419506073,0.00851440429688]
# [1.1328125,1.14453125]
# [1.14453125,1.15625]
# [1.15625,1.25]
# A=[-0.829193115234,0.4423828125]
# [1.15625,1.203125]
# A=[-0.484222412109,0.137042999268]
# [1.15625,1.1796875]
# [1.1796875,1.203125]
# [1.203125,1.25]
# A=[-0.539714813232,0.110595703125]
# [1.203125,1.2265625]
# [1.2265625,1.25]
# estoy aqui 3
# estoy aqui 2
# [1.25,2.0]
# [1.25,1.625]
# A=[-3.46875,2.853515625]
# [1.25,1.4375]
# A=[-1.74609375,1.15795898438]
# [1.25,1.34375]
# A=[-0.9638671875,0.426361083984]
# [1.25,1.296875]
# A=[-0.592529296875,0.0874443054199]
# [1.25,1.2734375]
# [1.2734375,1.296875]
# [1.296875,1.34375]
# A=[-0.64204788208,0.0682067871094]
# [1.296875,1.3203125]
# [1.3203125,1.34375]
# [1.34375,1.4375]
# A=[-1.08535766602,0.428466796875]
# [1.34375,1.390625]
# A=[-0.687652587891,0.0535011291504]
# [1.34375,1.3671875]
# [1.3671875,1.390625]
# [1.390625,1.4375]
# A=[-0.72872543335,0.0439453125]
# [1.390625,1.4140625]
# [1.4140625,1.4375]
# [1.4375,1.625]
# A=[-2.07641601562,1.341796875]
# [1.4375,1.53125]
# A=[-1.18872070312,0.453643798828]
# [1.4375,1.484375]
# A=[-0.7646484375,0.0401573181152]
# [1.4375,1.4609375]
# [1.4609375,1.484375]
# [1.484375,1.53125]
# A=[-0.794803619385,0.0427551269531]
# [1.484375,1.5078125]
# [1.5078125,1.53125]
# [1.53125,1.625]
# A=[-1.26901245117,0.5068359375]
# [1.53125,1.578125]
# A=[-0.818572998047,0.0523567199707]
# [1.53125,1.5546875]
# [1.5546875,1.578125]
# [1.578125,1.625]
# A=[-0.835338592529,0.069580078125]
# [1.578125,1.6015625]
# [1.6015625,1.625]
# [1.625,2.0]
# [1.625,1.8125]
# A=[-2.314453125,1.65747070312]
# [1.625,1.71875]
# A=[-1.3212890625,0.592987060547]
# [1.625,1.671875]
# A=[-0.844482421875,0.095043182373]
# [1.625,1.6484375]
# [1.6484375,1.671875]
# [1.671875,1.71875]
# A=[-0.845386505127,0.129364013672]
# [1.671875,1.6953125]
# [1.6953125,1.71875]
# [1.71875,1.8125]
# A=[-1.34060668945,0.717041015625]
# [1.71875,1.765625]
# A=[-0.837432861328,0.173160552979]
# [1.71875,1.7421875]
# [1.7421875,1.765625]
# [1.765625,1.8125]
# A=[-0.820003509521,0.22705078125]
# [1.765625,1.7890625]
# [1.7890625,1.8125]
# [1.8125,2.0]
# [1.8125,1.90625]
# A=[-1.32202148438,0.883941650391]
# [1.8125,1.859375]
# A=[-0.79248046875,0.291652679443]
# [1.8125,1.8359375]
# A=[-0.532653808594,0.00473928451538]
# [1.8125,1.82421875]
# [1.82421875,1.8359375]
# [1.8359375,1.859375]
# A=[-0.51161813736,0.0351219177246]
# [1.8359375,1.84765625]
# [1.84765625,1.859375]
# [1.859375,1.90625]
# A=[-0.754245758057,0.367584228516]
# [1.859375,1.8828125]
# A=[-0.487827301025,0.0683369636536]
# [1.859375,1.87109375]
# [1.87109375,1.8828125]
# [1.8828125,1.90625]
# A=[-0.461204051971,0.104461669922]
# [1.8828125,1.89453125]
# [1.89453125,1.90625]
# [1.90625,2.0]
# estoy aqui 3
# estoy aqui 3
# estoy aqui 3
# estoy aqui 3
# estoy aqui 3
# estoy aqui 2
# [2.0,5]
# [2.0,3.5]
# [2.0,2.75]
# [2.0,2.375]
# [2.0,2.1875]
# [2.0,2.09375]
# estoy aqui 2
# [2.09375,2.1875]
# A=[-0.989410400391,1.69116210938]
# [2.09375,2.140625]
# A=[-0.380767822266,0.938816070557]
# [2.09375,2.1171875]
# A=[-0.0813903808594,0.573264598846]
# [2.09375,2.10546875]
# [2.10546875,2.1171875]
# [2.1171875,2.140625]
# A=[-0.0221943855286,0.642734527588]
# [2.1171875,2.12890625]
# [2.12890625,2.140625]
# [2.140625,2.1875]
# A=[-0.265285491943,1.095703125]
# [2.140625,2.1640625]
# [2.1640625,2.1875]
# estoy aqui 2
# [2.1875,2.375]
# A=[-2.07934570312,3.791015625]
# [2.1875,2.28125]
# A=[-0.769775390625,2.07888793945]
# [2.1875,2.234375]
# A=[-0.134765625,1.26824569702]
# [2.1875,2.2109375]
# [2.2109375,2.234375]
# [2.234375,2.28125]
# [2.28125,2.375]
# A=[-0.487518310547,2.5341796875]
# [2.28125,2.328125]
# [2.328125,2.375]
# estoy aqui 2
# [2.375,2.75]
# A=[-4.541015625,9.375]
# [2.375,2.5625]
# A=[-1.552734375,5.02954101562]
# [2.375,2.46875]
# A=[-0.1376953125,3.06198120117]
# [2.375,2.421875]
# [2.421875,2.46875]
# [2.46875,2.5625]
# [2.5625,2.75]
# A=[-0.736083984375,6.59765625]
# [2.5625,2.65625]
# [2.65625,2.75]
# estoy aqui 2
# [2.75,3.5]
# A=[-10.453125,27.1875]
# [2.75,3.125]
# A=[-3.0,14.080078125]
# [2.75,2.9375]
# [2.9375,3.125]
# [3.125,3.5]
# estoy aqui 2
# [3.5,5]
# A=[-25.125,98.25]
# [3.5,4.25]
# A=[-4.3125,48.515625]
# [3.5,3.875]
# [3.875,4.25]
# [4.25,5]
# estoy aqui 3
# [Intervalo [2.0,2.0],
#  Intervalo [-0.0625,0.03125],
#  Intervalo [0.96875,1.0625],
#  Intervalo [1.90625,2.0],
#  Intervalo [2.0,2.09375]]

# %%
met_biseccion3(h, Intervalo(-1,5), 1/10. )
# Out:
# [Intervalo [2.0,2.0],
#  Intervalo [-0.0625,0.03125],
#  Intervalo [0.96875,1.0625],
#  Intervalo [1.90625,2.0],
#  Intervalo [2.0,2.09375]]

# %% [markdown]
# En este caso se observa que hay más intervalos de los que deberian (deberiamos tener solo tres intervalos), esto no se aún cómo corregirlo pero se debe a que aproximamos raices por la izquierda y por la derecha.

# %%
met_biseccion3(h2, Intervalo(-45.12458, 3.325689), 1/10. )
# Out:
# [Intervalo [-0.0809705390625,0.0136588925781],
#  Intervalo [0.959953208984,1.05458264063],
#  Intervalo [1.90624752539,2.00087695703]]

# %%
met_biseccion4(h2, Intervalo(-5,6), 0.0009)
# Out:
# [Intervalo [-0.00018310546875,0.00048828125],
#  Intervalo [0.99951171875,1.00018310547],
#  Intervalo [1.99987792969,2.00054931641]]

# %%
met_biseccion4(h, Intervalo(-0.4, 5.32), 0.0000000000000009)
# Out:
# [Intervalo [-2.20561719626e-16,4.14485850459e-16],
#  Intervalo [1.0,1.0],
#  Intervalo [2.0,2.0]]

# %% [markdown]
# Observese que a diferencia de la funcion met_biseccion3, con met_biseccion4 obtenemos solo tres intervalos.

# %%
met_biseccion4(h2, Intervalo(-45.12458, 3.325689), 0.0000000000000009)
# Out:
# [Intervalo [-4.62909351648e-16,2.09473200766e-16],
#  Intervalo [1.0,1.0],
#  Intervalo [2.0,2.0]]
